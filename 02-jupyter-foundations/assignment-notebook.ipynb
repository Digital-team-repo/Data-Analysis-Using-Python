# %% [markdown]
# # Lesson 2 Assignment Notebook: Build Your Notebook Skills
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/02-jupyter-foundations/assignment-notebook.ipynb) [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=02-jupyter-foundations/assignment-notebook.ipynb)
#
# This notebook gives you hands-on practice creating markdown cells and code cells.
#
# If you are unsure how to add a new cell or change a cell type, ask your instructor for help.

# %% [markdown]
# ## Part 1: Create a Heading in Markdown
# 1. Add a new **markdown** cell below this one.
# 2. In your new cell, type exactly: `# My First Notebook Heading`
# 3. Run the cell to render your heading.

# %% [markdown]
# ## Part 2: Bold and Italic Text
# 1. Add a new **markdown** cell.
# 2. In your new cell, type exactly:
#
# `This lesson is **fun** and *interactive*.`
#
# 3. Run the cell to check your formatting.

# %% [markdown]
# ## Part 3: Code Cell Basics
# Create a new **code** cell and type exactly:
#
# `8 + 12`
#
# Run the cell using `Shift + Enter` or the run button.

# %% [markdown]
# ## Part 4: PEMDAS Check
# In the cell below, type exactly:
#
# `10 + 6 / 2`

# %% [markdown]
# **Note:** Python follows PEMDAS (order of operations), so division happens before addition unless parentheses change the order.

# %% [markdown]
# ## Part 5: Beyond `print()`
# In a new code cell, type exactly:
#
# `len("data science")`
#
# Run the cell and observe the result.

# %% [markdown]
# ## Part 6: Quick Reflection
# Add a new **markdown** cell and answer:
# 1. What is one difference between a markdown cell and a code cell?
# 2. What is something you would like to explore more after this quick introduction to Jupyter Notebooks?
