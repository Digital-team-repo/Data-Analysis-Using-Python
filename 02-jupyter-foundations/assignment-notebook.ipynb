# %% [markdown]
# # Lesson 2 Assignment Notebook: Jupyter Foundations
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/02-jupyter-foundations/assignment-notebook.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=02-jupyter-foundations/assignment-notebook.ipynb)
#
# <div>
#   <div><span style="white-space: nowrap;"><strong>Course:</strong> ICD2O</span></div>
#   <div><span style="white-space: nowrap;"><strong>Lesson:</strong> 2 - Jupyter Notebook Foundations</span></div>
#   <div><span style="white-space: nowrap;"><strong>Student Name:</strong> <em>Type your name here</em></span></div>
#   <div><span style="white-space: nowrap;"><strong>Date:</strong> <em>YYYY-MM-DD</em></span></div>
# </div>
#
# ## Purpose
# In this assignment, you will practice notebook fundamentals: markdown cells, code cells, output behavior, and run order.
#
# ## Submission Instructions
# - Complete all parts in order.
# - Keep your answers in this notebook.
# - Submit this notebook with visible outputs.

# %% [markdown]
# ## Learning Targets
# By the end of this notebook, you should be able to:
# - create and edit markdown cells;
# - run code cells and read output;
# - explain why execution order matters;
# - describe one difference between markdown and code cells.

# %% [markdown]
# ## Key Vocabulary
# - **Markdown cell**: A notebook cell for written text.
# - **Code cell**: A notebook cell that runs Python.
# - **Output area**: The visible result from a code cell.
# - **Kernel/Runtime**: The engine that executes notebook code.
# - **PEMDAS**: Order of operations used in math expressions.

# %% [markdown]
# ## Part 1: Create a Heading in Markdown
# ### Task
# Create a new markdown cell below this section and type a heading with your own title.

# %% [markdown]
# ### Your Response (Part 1)
# _Create your heading markdown cell below this line._

# %% [markdown]
# ## Part 2: Bold and Italic Text
# ### Task
# Create one markdown sentence that uses **bold** and *italic* text.

# %% [markdown]
# ### Your Response (Part 2)
# _Create your formatted markdown sentence below this line._

# %% [markdown]
# ## Part 3: Code Cell Basics
# ### Task
# Run each expression in its own code cell:
# 1. `10 + 10`
# 2. `20 - 5`
# 3. `3 * 4`
# 4. `18 / 3`

# %%
10 + 10

# %%
20 - 5

# %%
3 * 4

# %%
18 / 3

# %% [markdown]
# ### Your Response (Part 3)
# What do you notice about where outputs appear in a notebook?
#
# _Write your answer below this line._

# %% [markdown]
# ## Part 4: PEMDAS Check
# ### Task
# Run this expression and record your result: `10 + 6 / 2`.

# %%
10 + 6 / 2

# %% [markdown]
# **Note:** Python follows PEMDAS. Division happens before addition unless parentheses change the order.

# %% [markdown]
# ### Your Response (Part 4)
# - What result did you get?
# - Why did Python return that result?
#
# _Write your answer below this line._

# %% [markdown]
# ## Part 5: Beyond `print()`
# ### Task
# Run the next code cell to compare direct output with `print()`.

# %%
value = 25
value
print("Value is", value)

# %% [markdown]
# ### Your Response (Part 5)
# What is one difference between direct output and `print()` output?
#
# _Write your answer below this line._

# %% [markdown]
# ## Part 6: Execution Order Check
# ### Task
# Run the following two cells in the wrong order first (cell B, then cell A), then rerun in the correct order.

# %%
# Cell A
number = 12

# %%
# Cell B
number + 8

# %% [markdown]
# ### Your Response (Part 6)
# - What happened when you ran Cell B first?
# - Why did rerunning in order fix it?
#
# _Write your answer below this line._

# %% [markdown]
# ## Final Reflection (Required)
# 1. What is one difference between a markdown cell and a code cell?
# 2. What part of Jupyter notebooks would you like to explore more?
#
# _Write your reflection below this line._

# %% [markdown]
# ## Success Criteria Checklist
# - [ ] I completed all assignment parts.
# - [ ] I ran all code cells successfully.
# - [ ] I answered each "Your Response" section.
# - [ ] I completed the final reflection.
# - [ ] My notebook includes visible outputs.
