# %% [markdown]
# # Lesson 2 Guided Practice: Notebook Anatomy
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/02-jupyter-foundations/demo-notebook.ipynb) [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=02-jupyter-foundations/demo-notebook.ipynb)
# ## Student Name
# Type your name here: ____________________________

# %% [markdown]
# ## Part 1: Markdown Cell Practice
# Add one sentence below explaining what this lesson is about.

# %% [markdown]
# Write your sentence here.

# %% [markdown]
# ## Part 2: Code Cell Practice
# Run the next code cell using `Shift + Enter` or by clicking the run button.

# %%
10 + 10

# %% [markdown]
# ### Output Check
# What output did you see?
#
# Type your answer: ____________________________

# %% [markdown]
# ## Part 2B: Multiple Expressions in One Cell
# Run the next code cell. Notice that you only see the output of the last line (`5 + 5`).

# %%
10 + 10
5 + 5

# %% [markdown]
# ### Why This Happens
# In a notebook code cell, only the last unassigned expression is displayed automatically.
# If you want to show both results, use `print()`.

# %%
print(10 + 10)
print(5 + 5)

# %% [markdown]
# ### Output Check
# What did you observe in the first cell compared with the `print()` cell?
#
# Type your answer: ____________________________

# %% [markdown]
# ## Part 3: Import Practice
# Run the next import cell.

# %%
import pandas as pd

# %% [markdown]
# ## Part 4: Execution Order Check
# Run the next cell. If you did not run the import cell first, you should see an error.

# %%
pd.Series([1, 2, 3])

# %% [markdown]
# ### Reflection
# 1. What happened when you ran the previous cell?
# 2. Why does execution order matter in notebooks?
# Create a new markdown cell and type your answers below. If you are unsure how to add a new cell, ask your instructor for help.
