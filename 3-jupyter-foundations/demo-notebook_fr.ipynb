# %% [markdown]
# # Leçon 3 : Carnet de démonstration interactif
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/3-jupyter-foundations/demo-notebook_fr.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=3-jupyter-foundations%2Fdemo-notebook_fr.ipynb)
#
# ## Nom de l’élève
#
# Saisis ton nom ici : ____________________________

# %% [markdown]
# ## Partie 1 : Exercice sur les cellules de texte
#
# Explique ci-dessous, en une phrase, le sujet de cette leçon.

# %% [markdown]
# Saisis ta phrase.

# %% [markdown]
# ## Partie 2A : Exercice sur les cellules de code
#
# Exécute la cellule de code suivante en utilisant `Maj + Entrée` ou en cliquant sur le bouton d’exécution.

# %%
10 + 10

# %% [markdown]
# ### Vérification de la sortie
#
# Quelle sortie as-tu obtenue?
#
# Saisis ta réponse : ____________________________

# %% [markdown]
# ## Partie 2B : Expressions multiples dans une même cellule
#
# Exécute la cellule de code suivante. Remarque que seule la sortie de la dernière ligne (`20 + 20`) s’affiche.

# %%
10 + 10
20 + 20

# %% [markdown]
# ### Pourquoi ce comportement?
#
# Dans une cellule de code d’un carnet, seule la dernière expression non attribuée s’affiche automatiquement. Pour afficher les deux résultats, utilise `print()`.

# %%
print(10 + 10)
print(20 + 20)

# %% [markdown]
# ### Vérification de la sortie
#
# Qu’as-tu observé dans la première cellule par rapport à la cellule utilisant `print()`?
#
# Saisis ta réponse : ____________________________

# %% [markdown]
# ## Partie 3 : Exercice sur l’importation
#
# Exécute la prochaine cellule d’importation.

# %%
import pandas as pd

# %% [markdown]
# ## Partie 4 : Vérification de l’ordre d’exécution
#
# Exécute la cellule suivante. Si tu n’as pas exécuté la cellule d’importation en premier, un message d’erreur devrait s’afficher.

# %%
pd.Series([1, 2, 3])

# %% [markdown]
# ### Réflexion
#
# Que s’est-il produit lors de l’exécution de la cellule précédente?
#
# Pourquoi l’ordre d’exécution est-il important dans les carnets? Crée une nouvelle cellule de texte et saisis tes réponses ci-dessous. Si tu ne sais pas comment insérer une nouvelle cellule, demande de l’aide à ton enseignante ou à ton enseignant.
#
# Saisis ta réflexion.
