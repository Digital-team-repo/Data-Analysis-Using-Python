# %% [markdown]
# # Lesson Three: Jupyter Notebook Foundations — Assignment Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/3-jupyter-foundations/assignment-notebook.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=3-jupyter-foundations%2Fassignment-notebook.ipynb)
#
# ## Student Information (Edit This Cell)
#
# **Student Name:** Type your name here
#
# **Date:** YYYY-MM-DD

# %% [markdown]
# ## Purpose
#
# In this assignment, you will practise notebook fundamentals: markdown cells, code cells, output behaviour and run order.

# %% [markdown]
# ## Submission Instructions
#
# - Complete all parts in order.
# - Keep your answers in this notebook.
# - Submit this notebook with visible outputs.

# %% [markdown]
# ## Learning Goals
#
# By the end of this notebook, you should be able to:
#
# - create and edit markdown cells
# - run code cells and read output
# - explain why execution order matters
# - describe one difference between markdown and code cells.

# %% [markdown]
# ## Key Vocabulary
#
# - **Markdown cell:** a notebook cell used for written text (headings, notes and explanations)
# - **Code cell:** a notebook cell that runs Python code
# - **Output area:** the visible result shown after a code cell runs.
# - **Kernel/Runtime:** the background engine that runs notebook code
# - **PEMDAS:** the order of operations Python uses when evaluating expressions

# %% [markdown]
# ## Part 1: Create a Heading in Markdown
#
# ### Task
#
# Create a new markdown cell below this section and type a heading with your own title.

# %% [markdown]
# ### Your Response
#
# Create your heading markdown cell.

# %% [markdown]
# ## Part 2: Bold and Italic Text
#
# ### Task
#
# Create one markdown sentence that uses bold and italic text.

# %% [markdown]
# ### Your Response
#
# Create your formatted markdown sentence.

# %% [markdown]
# ## Part 3: Code Cell Basics
#
# ### Task
#
# Run the code cell below without making any changes.
#
# Notice how many results are displayed.
#
# Now create four new code cells. Copy one expression into each code cell and run them individually.
#
# - `10 + 10`
# - `20 - 5`
# - `3 * 4`
# - `18 / 3`

# %%
10 + 10
20 - 5
3 * 4
18 / 3

# %% [markdown]
# ### Your Response
#
# When you ran the original code cell, how many results were displayed?
#
# What happened after you moved each expression into its own code cell?
#
# Why do you think Jupyter behaves this way?
#
# Type your answer.

# %% [markdown]
# ## Part 4: PEMDAS Check
#
# ### Task
#
# Run this expression and record your result: `10 + 6 / 2`.

# %%
10 + 6 / 2

# %% [markdown]
# **Note:** Python follows PEMDAS. Division happens before addition unless parentheses change the order.
#
# ### Your Response
#
# What result did you get?
#
# Why did Python return that result?
#
# Type your answer.

# %% [markdown]
# ## Part 5: Beyond `print()`
#
# ### Task
#
# Run the next code cell to compare direct output with `print()`.

# %%
value = 25
value
print("Value is", value)

# %% [markdown]
# ### Your Response
#
# What is one difference between direct output and `print()` output?
#
# Type your answer.

# %% [markdown]
# ## Part 6: Execution Order Check
#
# ### Task
#
# Run the following two cells in the wrong order first (cell B, then cell A), then rerun in the correct order.

# %%
# Cell A
number = 12

# %%
# Cell B
number + 8

# %% [markdown]
# ### Your Response
#
# What happened when you ran Cell B first?
#
# Why did rerunning in order fix it?
#
# Type your answer.

# %% [markdown]
# ## Final Reflection (Required)
#
# What is one difference between a markdown cell and a code cell?
#
# What part of Jupyter notebooks would you like to explore more?
#
# Type your reflection.

# %% [markdown]
# ## Success Criteria Checklist
#
# - [ ] I completed all assignment parts.
# - [ ] I ran all code cells successfully.
# - [ ] I answered each “Your Response” section.
# - [ ] I completed the final reflection.
# - [ ] My notebook includes visible outputs.
