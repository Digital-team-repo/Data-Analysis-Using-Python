# %% [markdown]
# # Arcade Night Leaderboard
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/3-jupyter-foundations/examples/arcade-leaderboard-notebook.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=3-jupyter-foundations%2Fexamples%2Farcade-leaderboard-notebook.ipynb)
#
# This notebook shows the same program as the dense script, but split into readable steps with explanations.

# %% [markdown]
# ## Step 1: Import tools

# %%
import random
from statistics import mean
import matplotlib.pyplot as plt

# %% [markdown]
# ## Step 2: Create sample class data

# %%
players = ["Avery", "Jordan", "Kai", "Mina", "Riley", "Sasha"]
scores = [random.randint(1200, 3800) for _ in players]
bonus_round = [random.randint(-300, 500) for _ in players]
final_scores = [s + b for s, b in zip(scores, bonus_round)]

# %% [markdown]
# ## Step 3: Rank and summarize results

# %%
ranked = sorted(zip(players, final_scores), key=lambda x: x[1], reverse=True)
ranked

# %%
print("Arcade Night Leaderboard")
for i, (name, score) in enumerate(ranked, start=1):
    print(f"{i}. {name}: {score}")

print(f"\nClass average score: {mean(final_scores):.1f}")
print(f"Top score gap: {ranked[0][1] - ranked[-1][1]}")

# %% [markdown]
# ## Step 4: Visualize the leaderboard

# %%
names = [n for n, _ in ranked]
values = [v for _, v in ranked]
colors = ["#1f77b4" if i == 0 else "#8fb9e3" for i in range(len(values))]

plt.figure(figsize=(8, 4))
plt.bar(names, values, color=colors)
plt.title("Arcade Night Final Scores")
plt.xlabel("Player")
plt.ylabel("Final Score")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
