# %% [markdown]
# # Lesson Three Interactive Demo Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/3-jupyter-foundations/demo-notebook.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=3-jupyter-foundations%2Fdemo-notebook.ipynb)
#
# ## Student Name
# Type your name here: ____________________________

# %% [markdown]
# ## Part 1: Markdown Cell Practice
#
# Add one sentence below explaining what this lesson is about.

# %% [markdown]
# Type your sentence.

# %% [markdown]
# ## Part 2A: Code Cell Practice
#
# Run the next code cell using `Shift + Enter` or by clicking the run button.

# %%
10 + 10

# %% [markdown]
# ### Output Check
# What output did you see?
#
# Type your answer: ____________________________

# %% [markdown]
# ## Part 2B: Multiple Expressions in One Cell
#
# Run this cell. Notice which line appears in the output.

# %%
10 + 10
5 + 5

# %% [markdown]
# ### Why This Happens
#
# Jupyter automatically prints the result of the last line in a code cell.

# %%
print(10 + 10)
print(5 + 5)

# %% [markdown]
# ### Output Check
# What output did you see this time?
#
# Type your answer: ____________________________

# %% [markdown]
# ## Part 3: Import Practice
#
# Run the cell below to load the pandas tool.

# %%
import pandas as pd

# %% [markdown]
# ## Part 4: Execution Order Check
#
# Run the cell below. Why does this work after Step 3?

# %%
pd.Series([1, 2, 3])

# %% [markdown]
# ### Reflection
# What happens if you restart the kernel and run Step 4 before Step 3?
#
# Type your answer: ____________________________
