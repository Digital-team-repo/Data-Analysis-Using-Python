# %% [markdown]
# # Lesson Six: Data Cleaning — Assignment Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/6-data-cleaning/notebook.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=6-data-cleaning%2Fnotebook.ipynb)

# %% [markdown]
# ## Student Information (Edit This Cell)
# **Student Name:** Type your name here
# **Date:** YYYY-MM-DD

# %% [markdown]
# ## Purpose
#
# In this assignment, you will clean real-world style data issues in three short examples.

# %% [markdown]
# ## Submission Instructions
# - Complete all code cells in order.
# - Write responses in each “Your Response” markdown section.
# - Leave your final notebook with outputs visible before submitting.

# %% [markdown]
# ## Learning Goals
# By the end of this notebook, you should be able to:
# - identify missing values (`NaN`) in a table
# - remove duplicate rows
# - explain why some files need `skiprows`
# - explain how cleaning improves analysis quality before interpretation.

# %% [markdown]
# ## Key Vocabulary
# - **NaN:** stands for Not a Number and usually means a value is missing or invalid in your dataset
# - **Duplicate row:** a row that appears more than once in a dataset
# - **Metadata line:** a non-data line in a file (for example, a title or note) that appears before the real header
# - **skiprows:** an option in file-reading commands (like `pd.read_csv`) that skips a specified number of lines

# %% [markdown]
# ## Step 1: Import pandas
#
# Big picture: We use pandas to load and clean CSV files.

# %%
import pandas as pd

# %% [markdown]
# ## Step 2: Import Data and Remove Missing values (`NaN`)
#
# Big picture: First, inspect the raw table and look for missing values.
#
# ### Task
# - Load the file and display the first rows.
# - Remove rows with missing values.

# %%
data1_url = "https://raw.githubusercontent.com/Digital-team-repo/Data-Analysis-Using-Python/main/6-data-cleaning/data1_en.csv"
df1 = pd.read_csv(data1_url)
df1.head()

# %%
df1 = df1.dropna()
df1.head()

# %% [markdown]
# ### Your Response (Example 1)
# - Which row(s) looked incomplete before cleaning?
# - What visible change do you see after `dropna()`?
#
# Type your answer below this line.

# %% [markdown]
# ## Step 3: Remove Duplicate rows
#
# Big picture: Now focus on repeated rows in the same dataset.
#
# ### Task
# - Reload the same file as a fresh DataFrame.
# - Remove duplicate rows.

# %%
df2 = pd.read_csv(data1_url)
df2 = df2.drop_duplicates()
df2.head()

# %% [markdown]
# ### Your Response (Example 2)
# - Why did we reload the dataset before cleaning duplicates?
# - How does `drop_duplicates()` improve table quality?
#
# Type your answer below this line.

# %% [markdown]
# ## Step 4: Skip Extra lines before the header
#
# Big picture: Some files include title/notes lines before the real table.
#
# ### Task
# - Show the first 4 lines (non-data metadata lines).
# - Use `skiprows=4` to read the real table header and rows.

# %%
data2_url = "https://raw.githubusercontent.com/Digital-team-repo/Data-Analysis-Using-Python/main/6-data-cleaning/data2_en.csv"
df3_first_four_lines = pd.read_csv(data2_url, header=None, nrows=4)
df3_first_four_lines

# %%
df3 = pd.read_csv(data2_url, skiprows=4)
df3.head()

# %% [markdown]
# ### Your Response (Example 3)
# - Why does `pd.read_csv(data2_url)` fail if we do not use `skiprows=4`?
# - In your own words, what does `skiprows=4` do?
#
# Type your answer below this line.

# %% [markdown]
# ## Final Reflection (Required)
#
# Answer each question in complete sentences:
# 1. Which cleaning example was easiest for you? Why?
# 2. Why is data cleaning necessary before creating charts or calculating statistics?
# 3. What could happen if an analyst forgets to check for missing or duplicate data?
#
# Type your answers below this line.

# %% [markdown]
# ## Success Criteria Checklist
# - [ ] My notebook includes visible outputs for each example.
# - [ ] I removed `NaN` values in Example 1.
# - [ ] I removed duplicate rows in Example 2.
# - [ ] I loaded the metadata-header file cleanly with `skiprows=4` in Example 3.
# - [ ] I completed all response sections and final reflection questions.
