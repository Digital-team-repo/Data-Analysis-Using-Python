# %% [markdown]
# # Lesson 5: Data Cleaning Assignment Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/6-data-cleaning/notebook.ipynb) [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=6-data-cleaning/notebook.ipynb)

# %% [markdown]
# ## Student Information (Edit This Cell)
# **Student Name:** _Type your name here_
# **Date:** _YYYY-MM-DD_

# %% [markdown]
# **Course:** ICD2O
# **Lesson:** 5 - Data Cleaning
#
# ## Purpose
# In this assignment, you will clean real-world style data issues in three short examples.
#
# ## Submission Instructions
# - Complete all code cells in order.
# - Write responses in each "Your Response" markdown section.
# - Leave your final notebook with outputs visible before submitting.

# %% [markdown]
# ## Learning Goals
# By the end of this notebook, you should be able to:
# - identify missing values (`NaN`) in a table;
# - remove duplicate rows;
# - explain why some files need `skiprows`;
# - explain how cleaning improves analysis quality before interpretation.

# %% [markdown]
# ## Key Vocabulary
# - **NaN**: A missing value in a table.
# - **Duplicate row**: A repeated record in a dataset.
# - **Metadata line**: Extra non-table lines at the top of a file.
# - **`skiprows`**: A pandas option that skips lines before reading table data.

# %% [markdown]
# ## Step 1: Import pandas
# Big picture: We use pandas to load and clean CSV files.

# %%
import pandas as pd

# %% [markdown]
# ## Example 1: Missing values (`NaN`)
# Big picture: First, inspect the raw table and look for missing values.
#
# ### Task
# 1. Load the file and display the first rows.
# 2. Remove rows with missing values.
# 3. Display the first rows again to show what changed.

# %%
data1_url = "https://raw.githubusercontent.com/Digital-team-repo/Data-Analysis-Using-Python/main/6-data-cleaning/data1_en.csv"
df1 = pd.read_csv(data1_url)
df1.head()

# %%
df1 = df1.dropna()
df1.head()

# %% [markdown]
# ### Your Response (Example 1)
# - Which row(s) looked incomplete before cleaning?
# - What visible change do you see after `dropna()`?
#
# _Write your answer below this line._

# %% [markdown]
# ## Example 2: Duplicate rows
# Big picture: Now focus on repeated rows in the same dataset.
#
# ### Task
# 1. Reload the same file as a fresh DataFrame.
# 2. Remove duplicate rows.
# 3. Display the first rows to confirm the cleanup.

# %%
df2 = pd.read_csv(data1_url)
df2 = df2.drop_duplicates()
df2.head()

# %% [markdown]
# ### Your Response (Example 2)
# - Why did we reload the dataset before cleaning duplicates?
# - How does `drop_duplicates()` improve table quality?
#
# _Write your answer below this line._

# %% [markdown]
# ## Example 3: Extra lines before the header
# Big picture: Some files include title/notes lines before the real table.
#
# ### Task
# 1. Show the first 4 lines (non-data metadata lines).
# 2. Use `skiprows=4` to read the real table header and rows.

# %%
data2_url = "https://raw.githubusercontent.com/Digital-team-repo/Data-Analysis-Using-Python/main/6-data-cleaning/data2_en.csv"
df3_first_four_lines = pd.read_csv(data2_url, header=None, nrows=4)
df3_first_four_lines

# %%
df3 = pd.read_csv(data2_url, skiprows=4)
df3.head()

# %% [markdown]
# ### Your Response (Example 3)
# - Why does `pd.read_csv(data2_url)` fail if we do not use `skiprows=4`?
# - In your own words, what does `skiprows=4` do?
#
# _Write your answer below this line._

# %% [markdown]
# ## Final Reflection (Required)
# Answer each question in complete sentences:
# 1. Which cleaning example was easiest for you? Why?
# 2. Which cleaning example was hardest for you? Why?
# 3. How can unclean data lead to weak or incorrect conclusions?
#
# _Write your final reflection below this line._

# %% [markdown]
# ## Success Criteria Checklist
# Before submitting, confirm:
# - [ ] I ran all code cells successfully.
# - [ ] I completed all "Your Response" sections.
# - [ ] I completed the Final Reflection.
# - [ ] My notebook includes visible outputs for each example.
