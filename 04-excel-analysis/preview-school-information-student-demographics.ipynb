# %% [markdown]
# # Lesson 4 Data Preview: School Information and Student Demographics
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/04-excel-analysis/preview-school-information-student-demographics.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=04-excel-analysis/preview-school-information-student-demographics.ipynb)
#
# ## Objective
# Import an Excel file and examine the distribution of school enrolment values.
#
# ## Dataset
# - Source page: https://data.ontario.ca/dataset/school-information-and-student-demographics
# - Classroom Excel file: `school-demographics-classroom.xlsx`

# %% [markdown]
# ## Step 1: Import libraries
# Big picture: We load the tools needed to open Excel data and draw a chart.
#
# Technical details: `pandas` creates a DataFrame named `df`. `plotly.express` builds the chart.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Step 2: Load the Excel file
# Big picture: We open the classroom-ready Excel file stored in this same folder.
#
# Technical details: `pd.read_excel()` reads the spreadsheet into `df`.

# %%
data_file = "school-demographics-classroom.xlsx"
df = pd.read_excel(data_file)
df.head()

# %% [markdown]
# ## Step 3: Check your table
# Big picture: We confirm the columns before plotting.
#
# Technical details: `df.columns` is a property, while `df.head()` is a method.

# %%
df.columns
df.shape

# %% [markdown]
# ## Step 4: Create the chart
# Big picture: We create one clear visualization to spot a pattern quickly.
#
# Technical details: The histogram uses `Enrolment` values to show how common different school sizes are.

# %%
fig = px.histogram(df, x='Enrolment', nbins=30, title='Distribution of School Enrolment')
fig.update_layout(template='plotly_white')
fig.show()
