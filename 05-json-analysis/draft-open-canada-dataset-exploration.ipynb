# %% [markdown]
# # Lesson 5 Draft: JSON Data Quick Look\n\n[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/05-json-analysis/draft-open-canada-dataset-exploration.ipynb) \n[![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=05-json-analysis/draft-open-canada-dataset-exploration.ipynb)\n\n**Objective:** Do a first quick check of JSON data structure using pandas.\n\n**Dataset page:** https://open.canada.ca/data/en/dataset/d38de914-c94c-429b-8ab1-8776c31643e3\n\n**Date/author:** 2026-05-24 / Team 2 draft\n

# %% [markdown]
# ## Step 1: Set the JSON URL\nBig picture: We store the JSON link in one variable so it is easy to change later.

# %%
data_url = "https://open.canada.ca/data/en/api/3/action/package_show?id=d38de914-c94c-429b-8ab1-8776c31643e3"

# %% [markdown]
# ## Step 2: Import pandas\nBig picture: We use pandas to read JSON and inspect it as tables.

# %%
import pandas as pd

# %% [markdown]
# ## Step 3: Read the JSON\nBig picture: This first load shows the top-level API wrapper table.

# %%
df = pd.read_json(data_url)\ndf

# %% [markdown]
# ## Step 4: Check top-level columns\nBig picture: `help`, `success`, and `result` tell us this is an API wrapper, not final analysis rows yet.

# %%
df.columns

# %% [markdown]
# ## Step 5: Open the `result` section\nBig picture: `result` holds the dataset details, including file/resource links.

# %%
result = df.loc["result", 0]\ntype(result), list(result.keys())[:10]

# %% [markdown]
# ## Step 6: Build a table of resources\nBig picture: This gives us direct file links we can test in later draft notebooks.

# %%
resources = result.get("resources", [])\nresources_df = pd.DataFrame(resources)\nresources_df[["name", "format", "url"]].head(15)

# %% [markdown]
# ## Step 7: Count rows in the resource table\nBig picture: We check how many downloadable resources are attached to this dataset page.

# %%
len(resources_df)

# %% [markdown]
# ## Quick Reflection (Draft)\n1. Why do we see `help`, `success`, and `result` first?\n2. Which resource format looks easiest for a beginner follow-up notebook?\n3. Which one direct `url` should we test next with `pd.read_json` or `pd.read_csv`?
