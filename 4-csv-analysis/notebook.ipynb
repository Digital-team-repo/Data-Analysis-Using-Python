# %% [markdown]
# # Lesson Four: Importing CSV Files — Assignment Notebook
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/4-csv-analysis/notebook.ipynb)
# [![Open In Callysto](https://img.shields.io/badge/Open%20In-Callysto-blue)](https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=4-csv-analysis%2Fnotebook.ipynb)

# %% [markdown]
# ## Student Information (Edit This Cell)
# **Student Name:** Type your name here
# **Date:** YYYY-MM-DD
# **Course:** ICD2O
# **Lesson:** 4 — Importing CSV Files

# %% [markdown]
# ## Purpose
#
# In this assignment, you will import a CSV file, verify that it loaded correctly, create one simple chart, and write evidence-based analysis statements.

# %% [markdown]
# ## Submission Instructions
# - Complete all parts in order.
# - Write answers in each “Your Response” section.
# - Submit this notebook with visible outputs.

# %% [markdown]
# ## Learning Goals
# By the end of this notebook, you should be able to:
# - import a CSV file using pandas
# - verify table structure with `columns`, `head()`, and `tail()`
# - create a scatter plot using `plotly.express`
# - write evidence-based observations from data.

# %% [markdown]
# ## Key Vocabulary
# - **CSV:** Comma-Separated Values, a common text format for tabular data
# - **pd.read_csv():** pandas function used to load a CSV file into a DataFrame
# - **df.head():** method that previews the top rows of a DataFrame
# - **px.scatter():** plotly.express function used to create scatter plots

# %% [markdown]
# ## Step 1: Import libraries
#
# Big picture: We load pandas for table operations and plotly for charts.
#
# Technical details: `import pandas as pd` loads pandas with the `pd` nickname. `import plotly.express as px` loads plotting tools.

# %% [markdown]
# ## Step 1: Import libraries
#
# Big picture: We load pandas for table operations and plotly for charts.
#
# Technical details: `import pandas as pd` loads pandas with the `pd` nickname. `import plotly.express as px` loads plotting tools.

# %% [markdown]
# ## Part 1: Open and Load the CSV
#
# Big picture: We load the CSV file into a DataFrame variable named `df`.
#
# Technical details: `pd.read_csv(data_url)` reads the remote CSV file into memory.

# %% [markdown]
# ## Part 1: Open and Load the CSV
#
# Big picture: We load the CSV file into a DataFrame variable named `df`.
#
# Technical details: `pd.read_csv(data_url)` reads the remote CSV file into memory.

# %% [markdown]
# ## Part 2: Check That the Data Loaded Correctly
#
# Big picture: Inspect columns and top/bottom rows to confirm the file loaded cleanly.
#
# Technical details: `df.columns` shows column names. `df.head()` shows the first 5 rows. `df.tail()` shows the last 5 rows.

# %% [markdown]
# ## Part 2: Check That the Data Loaded Correctly
#
# Big picture: Inspect columns and top/bottom rows to confirm the file loaded cleanly.
#
# Technical details: `df.columns` shows column names. `df.head()` shows the first 5 rows. `df.tail()` shows the last 5 rows.

# %%
df.columns

# %%
df.head()

# %% [markdown]
# ### Your Response (Part 2)
# - How many columns are in the dataset?
# - What are the names of the main data columns?
# - What year range is covered between `head()` and `tail()`?
#
# Type your answers below this line.

# %% [markdown]
# ## Part 3: Make One Simple Chart
#
# Big picture: Create a scatter plot of Year vs Departure to visualize the temperature trend.
#
# Technical details: `px.scatter()` uses `df` with `x="Year"` and `y="Departure"`.

# %% [markdown]
# ## Part 3: Make One Simple Chart
#
# Big picture: Create a scatter plot of Year vs Departure to visualize the temperature trend.
#
# Technical details: `px.scatter()` uses `df` with `x="Year"` and `y="Departure"`.

# %% [markdown]
# ### Your Response (Part 3)
# - Describe the general trend you see in the scatter plot.
# - Are recent departure values mostly positive or negative?
# - What does a positive departure value mean in this dataset?
#
# Type your answers below this line.

# %% [markdown]
# ## Part 4: Computational Thinking Reflection
#
# Big picture: Connect data analysis steps to computational thinking principles.

# %% [markdown]
# ### Your Response (Part 4)
# - **Decomposition:** How did splitting this task into steps (import -> load -> inspect -> chart) help you complete the analysis?
# - **Pattern Recognition:** What pattern did you observe when comparing earlier years to recent years?
#
# Type your answers below this line.

# %% [markdown]
# ## Success Criteria Checklist
# - [ ] My notebook loaded the CSV file without errors.
# - [ ] I displayed `head()` and `tail()` output.
# - [ ] My scatter plot renders clearly with title and axis labels.
# - [ ] I answered all reflection questions in complete sentences.
