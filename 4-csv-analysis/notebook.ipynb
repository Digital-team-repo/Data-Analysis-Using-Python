# %% [markdown]
# # Lesson Four Assignment Notebook: Importing CSV Files
#
# <a href="https://colab.research.google.com/github/Digital-team-repo/Data-Analysis-Using-Python/blob/main/4-csv-analysis/notebook.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" width="170" height="26"></a> <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2FDigital-team-repo%2FData-Analysis-Using-Python&branch=main&subPath=4-csv-analysis/notebook.ipynb"><img src="https://img.shields.io/badge/Open%20In-Callysto-blue" width="170" height="26"></a>

# %% [markdown]
# ## Student Information (Edit This Cell)
# **Student Name:** _Type your name here_
# **Date:** _YYYY-MM-DD_

# %% [markdown]
# **Course:** ICD2O
# **Lesson:** 3 - Importing CSV Files
#
# ## Purpose
# In this assignment, you will import a CSV file, verify that it loaded correctly, create one simple chart, and write evidence-based analysis statements.
#
# ## Submission Instructions
# - Complete all parts in order.
# - Write answers in each "Your Response" section.
# - Submit this notebook with visible outputs.

# %% [markdown]
# ## Learning Goals
# By the end of this notebook, you should be able to:
# - load CSV data using `data_url` and `pd.read_csv(data_url)`;
# - inspect table structure using `df.columns`, `df.head()`, and `df.tail()`;
# - create one simple chart from imported CSV data;
# - write an observation, an interpretation, and one limitation/caution;
# - explain decomposition, pattern recognition, abstraction, and algorithm design in your workflow.

# %% [markdown]
# ## Key Vocabulary
# - **import**: A Python command used to bring a library into the notebook.
# - **pandas (`pd`)**: A Python library for table-shaped data.
# - **data_url**: A variable name that stores the CSV link.
# - **`pd.read_csv(data_url)`**: Loads CSV data into a DataFrame.
# - **DataFrame (`df`)**: The table created after loading with pandas.
# - **`df.columns`**: Shows column names.
# - **`df.head()`**: Shows the first rows.
# - **`df.tail()`**: Shows the last rows.

# %% [markdown]
# ## Step 1: Import libraries
# Big picture: We import the tools needed to load and graph CSV data.

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Part 1: Open and Load the CSV
# ### Task
# Use the provided `data_url` and load the file with `pd.read_csv(data_url)`.

# %%
data_url = "https://raw.githubusercontent.com/Digital-team-repo/Data-Analysis-Using-Python/main/4-csv-analysis/data_en.csv"
df = pd.read_csv(data_url)
df.head()

# %% [markdown]
# ## Part 2: Check That the Data Loaded Correctly
# ### Task
# Run structure-check commands and answer the response prompts.

# %%
df.columns

# %%
df.head()

# %%
df.tail()

# %% [markdown]
# ### Your Response (Part 2)
# 1. List the column names you see from `df.columns`.
#
# 2. What does `df.head()` show?
#
# 3. What changed (and what stayed the same) when you ran `df.tail()`?
#
# _Write your answers below this line._

# %% [markdown]
# ## Part 3: Make One Simple Chart
# ### Task
# Create one scatter plot from the CSV data.

# %%
fig = px.scatter(
    df,
    x="Year",
    y="Temperature departure (degree Celsius)",
    title="Temperature Change in Canada (Annual)"
)
fig.show()

# %% [markdown]
# ### Your Response (Part 3)
#
# #### Part A: Technical Process
# 1. In the chart code, what column is used for the x-axis, and what column is used for the y-axis?
#
# 2. Explain what each parameter does in this chart command: `x=`, `y=`, and `title=`.
#
# 3. If you added a trend line to this graph, what direction would you expect it to slope? Explain briefly.
#
# #### Part B: Data Interpretation
# 4. What overall trend do you notice in the graph? Use evidence from specific years or ranges of years.
#
# 5. Compare temperature departures before 1980 and after 2000. What differences do you notice, and what is one possible reason for those differences?
#
# 6. Identify one year that appears unusual compared to nearby years. Why might it stand out?
#
# 7. What is one conclusion supported by the graph, and one conclusion that is **not** supported by the graph?
#
# 8. Why is it important to look at many years of data instead of just one or two years?
#
# 9. Open question: What does this plot make you wonder about the data, and what additional data would help answer that question?
#
# _Write your answers below this line._

# %% [markdown]
# ## Part 4: Computational Thinking Reflection
# Use one sentence for each concept to explain how you used it in this lesson.

# %% [markdown]
# ### Your Response (Part 4)
# 1. **Decomposition**: How did you break the task into smaller steps?
#
# 2. **Pattern Recognition**: What pattern did you notice in the table structure or chart?
#
# 3. **Abstraction**: What did you focus on, and what details did you set aside?
#
# 4. **Algorithm Design**: What repeatable sequence did you follow from import to interpretation?
#
# _Write your answers below this line._

# %% [markdown]
# ## Success Criteria Checklist
# - [ ] I imported CSV data using `data_url` and `pd.read_csv(data_url)`.
# - [ ] I checked structure using `df.columns`, `df.head()`, and `df.tail()`.
# - [ ] I created one simple chart from imported data.
# - [ ] I wrote an observation and evidence-based interpretation.
# - [ ] I identified one limitation/caution.
# - [ ] I completed computational thinking reflections.
